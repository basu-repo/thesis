# %% [markdown]
# # 50 CNN GNN Transformer
#
# Transformer-based trajectory model using the new `08` dataset fields. Saves metrics, weights, plots, and predictions to disk.

# %%
import gc
import json
import sys
from pathlib import Path

import torch

gc.collect()
try:
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.ipc_collect()
except Exception:
    pass

PROJECT_ROOT = Path.home() / "Documents/Thesis"
PIPELINE_ROOT = PROJECT_ROOT / "model_training"
if str(PIPELINE_ROOT) not in sys.path:
    sys.path.insert(0, str(PIPELINE_ROOT))

from training.notebook_workflow import (
    CNNGNNLSTMTrajectoryPredictor,
    CNNGNNLSTMTransformerTrajectoryPredictor,
    CNNGNNTransformerTrajectoryPredictor,
    CNNLSTMTrajectoryPredictor,
    ScanGoalTrajectoryDataset,
    ScanGraphTrajectoryDataset,
    collate_scan,
    collate_scan_graph,
    describe_dataloaders,
    describe_model,
    describe_shared_artifacts,
    device_from_flag,
    evaluate_trajectory_model,
    finish_runtime_report,
    load_or_build_shared_artifacts,
    make_dataloaders,
    prepare_result_dirs,
    run_constant_velocity_baseline,
    save_final_trajectory_evaluation,
    start_runtime_report,
    set_seed,
    timestamp_tag,
    train_trajectory_model,
)

# %%
SEED = 42
PAST_LEN = 10
FUTURE_LEN = 5
TRAIN_RATIO = 0.70
VAL_RATIO = 0.15
MAX_SAMPLES = None
USE_CPU = False

BATCH_SIZE = 64
EPOCHS = 30
EARLY_STOPPING_PATIENCE = 5
LR = 1e-3
WEIGHT_DECAY = 1e-4

GOAL_DIM = 13
NODE_DIM = 12
EDGE_DIM = 8
HIDDEN_DIM = 128
GRAPH_HIDDEN = 96
DROPOUT = 0.10
MSG_PASSES = 2
TRANSFORMER_HEADS = 4
TRANSFORMER_LAYERS = 2
TRANSFORMER_FF = 256

device = device_from_flag(USE_CPU)
print("Device:", device)
# Out:
# Device: cuda

# %%
shared_runtime = start_runtime_report(
    stage_name="shared_data_split",
    output_dir=PIPELINE_ROOT / "results",
    context={"past_len": PAST_LEN, "future_len": FUTURE_LEN, "seed": SEED},
)
set_seed(SEED)
streams, sample_table, split_info, sample_table_path, split_path = load_or_build_shared_artifacts(
    past_len=PAST_LEN,
    future_len=FUTURE_LEN,
    seed=SEED,
    train_ratio=TRAIN_RATIO,
    val_ratio=VAL_RATIO,
)
print("Sample table:", sample_table_path)
print("Split path:", split_path)
print("Split strategy:", split_info["split_strategy"])
print("Episode count:", split_info["episode_count"])
print("Train / Val / Test samples:", len(split_info["train_indices"]), len(split_info["val_indices"]), len(split_info["test_indices"]))
print("Train episodes:", split_info["train_episode_ids"])
print("Val episodes:", split_info["val_episode_ids"])
print("Test episodes:", split_info["test_episode_ids"])
shared_runtime_summary = finish_runtime_report(
    shared_runtime,
    extra=describe_shared_artifacts(
        streams=streams,
        sample_table=sample_table,
        split_info=split_info,
        sample_table_path=sample_table_path,
        split_path=split_path,
    ),
)
print(json.dumps(shared_runtime_summary, indent=2))
# Out:
# [runtime] shared_data_split start: 2026-05-23T11:54:50 summary=/home/basudeo/Documents/Thesis/model_training/results/runtime/20260523_115450_shared_data_split_runtime_summary.json
# Sample table: /home/basudeo/Documents/Thesis/model_training/results/train_ready/sample_table_seed42_past10_future5.json
# Split path: /home/basudeo/Documents/Thesis/model_training/results/splits/trajectory_split_seed42_past10_future5.json
# Split strategy: episode
# Episode count: 8
# Train / Val / Test samples: 36405 6082 9219
# Train episodes: ['run_model_20260522_203433', 'run_model_20260522_204215', 'run_model_20260523_013946', 'run_model_20260523_015017', 'run_model_20260522_202537']
# Val episodes: ['run_model_20260523_013116']
# Test episodes: ['run_model_20260522_201207', 'run_model_20260522_201854']
# [runtime] shared_data_split done: start=2026-05-23T11:54:50 end=2026-05-23T11:54:54 elapsed_s=4.451 peak_cpu=28.80% peak_rss_mb=1167.98 peak_gpu_alloc_mb=0.00
# {
#   "stage_name": "shared_data_split",
#   "timestamp": "20260523_115450",
#   "wall_start_iso": "2026-05-23T11:54:50",
#   "wall_end_iso": "2026-05-23T11:54:54",
#   "elapsed_s": 4.451,
#   "sample_count": 51706,
#   "context": {
#     "past_len": 10,
#     "future_len": 5,
#     "seed": 42
#   },
#   "avg_system_cpu_percent": 12.55,
#   "peak_system_cpu_percent": 28.8,
#   "avg_system_memory_percent": 31.825,
#   "peak_system_memory_percent": 33.0,
#   "avg_process_cpu_percent": 74.025,
#   "peak_process_cpu_percent": 100.2,
#   "avg_process_rss_mb": 891.165,
#   "peak_process_rss_mb": 1167.98,
#   "peak_gpu_memory_allocated_mb": 0.0,
#   "peak_gpu_memory_reserved_mb": 0.0,
#   "peak_gpu_max_memory_allocated_mb": 0.0,
#   "peak_gpu_max_memory_reserved_mb": 0.0,
#   "min_gpu_memory_free_mb": 5509.312,
#   "gpu_memory_total_mb": 5928.438,
#   "summary_path": "/home/basudeo/Documents/Thesis/model_training/results/runtime/20260523_115450_shared_data_split_runtime_summary.json",
#   "samples_path": "/home/basudeo/Documents/Thesis/model_training/results/runtime/20260523_115450_shared_data_split_runtime_samples.csv",
#   "episode_count": 8,
#   "total_frame_count": 51818,
#   "train_sample_count": 36405,
#   "val_sample_count": 6082,
#   "test_sample_count": 9219,
#   "frame_file_count": 8,
#   "frame_files_total_size_mb": 56.592,
#   "manifest_files_total_size_mb": 0.005,
#   "sample_table_size_mb": 42.886,
#   "split_file_size_mb": 3.195,
#   "split_strategy": "episode",
#   "train_episode_count": 5,
#   "val_episode_count": 1,
#   "test_episode_count": 2
# }

# %%
MODEL_SLUG = "cnn_gnn_transformer"
TIMESTAMP = timestamp_tag()
result_dir, weight_dir, plot_dir = prepare_result_dirs(MODEL_SLUG)

dataset = ScanGraphTrajectoryDataset(streams, sample_table, PAST_LEN)
train_loader, val_loader, test_loader = make_dataloaders(
    dataset,
    split_info,
    batch_size=BATCH_SIZE,
    collate_fn=collate_scan_graph,
    max_samples=MAX_SAMPLES,
)
loader_stats = describe_dataloaders(train_loader=train_loader, val_loader=val_loader, test_loader=test_loader)

model = CNNGNNTransformerTrajectoryPredictor(
    goal_dim=GOAL_DIM,
    node_dim=NODE_DIM,
    edge_dim=EDGE_DIM,
    hidden_dim=HIDDEN_DIM,
    graph_hidden=GRAPH_HIDDEN,
    future_len=FUTURE_LEN,
    dropout=DROPOUT,
    msg_passes=MSG_PASSES,
    num_heads=TRANSFORMER_HEADS,
    num_layers=TRANSFORMER_LAYERS,
    ff_dim=TRANSFORMER_FF,
).to(device)
model_stats = describe_model(model)
notebook_runtime = start_runtime_report(
    stage_name=f"{MODEL_SLUG}_notebook_run",
    output_dir=result_dir,
    context={
        "model_slug": MODEL_SLUG,
        "timestamp": TIMESTAMP,
        "past_len": PAST_LEN,
        "future_len": FUTURE_LEN,
        **loader_stats,
        **model_stats,
    },
)

train_out = train_trajectory_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    device=device,
    model_slug=MODEL_SLUG,
    timestamp=TIMESTAMP,
    split_path=split_path,
    sample_table_path=sample_table_path,
    result_dir=result_dir,
    weight_dir=weight_dir,
    plot_dir=plot_dir,
    epochs=EPOCHS,
    patience=EARLY_STOPPING_PATIENCE,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    extra_manifest={"family": "scan_graph_transformer", "future_len": FUTURE_LEN, "msg_passes": MSG_PASSES},
    runtime_output_dir=result_dir,
    runtime_context={
        **loader_stats,
        **model_stats,
        **describe_shared_artifacts(
            streams=streams,
            sample_table=sample_table,
            split_info=split_info,
            sample_table_path=sample_table_path,
            split_path=split_path,
        ),
    },
)
test_eval = evaluate_trajectory_model(model, test_loader, device)
notebook_runtime_summary = finish_runtime_report(
    notebook_runtime,
    extra={
        **loader_stats,
        **model_stats,
        "test_sample_count": int(len(test_loader.dataset)),
    },
)
final_metrics = save_final_trajectory_evaluation(
    model_slug=MODEL_SLUG,
    timestamp=TIMESTAMP,
    train_out=train_out,
    test_eval=test_eval,
    split_path=split_path,
    sample_table_path=sample_table_path,
    result_dir=result_dir,
    plot_dir=plot_dir,
    notebook_runtime=notebook_runtime_summary,
)
print(json.dumps(final_metrics, indent=2))
# Out:
# [runtime] cnn_gnn_transformer_notebook_run start: 2026-05-23T11:54:55 summary=/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/runtime/20260523_115455_cnn_gnn_transformer_notebook_run_runtime_summary.json
# [runtime] cnn_gnn_transformer_training start: 2026-05-23T11:54:55 summary=/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/runtime/20260523_115455_cnn_gnn_transformer_training_runtime_summary.json
# [cnn_gnn_transformer] start: epochs=30 patience=5 train_batches=569 val_batches=96
# [cnn_gnn_transformer] epoch 01/30 train_loss=0.000850 val_loss=0.000052 val_ADE=0.010193 val_FDE=0.010200 val_RMSE=0.014474 best_ADE=0.010193 status=improved
# [cnn_gnn_transformer] epoch 02/30 train_loss=0.000539 val_loss=0.000145 val_ADE=0.020374 val_FDE=0.031104 val_RMSE=0.024059 best_ADE=0.010193 status=no_improve(1/5)
# [cnn_gnn_transformer] epoch 03/30 train_loss=0.000522 val_loss=0.000050 val_ADE=0.009634 val_FDE=0.009534 val_RMSE=0.014138 best_ADE=0.009634 status=improved
# [cnn_gnn_transformer] epoch 04/30 train_loss=0.000513 val_loss=0.000042 val_ADE=0.008954 val_FDE=0.006386 val_RMSE=0.013027 best_ADE=0.008954 status=improved
# [cnn_gnn_transformer] epoch 05/30 train_loss=0.000511 val_loss=0.000043 val_ADE=0.008732 val_FDE=0.005679 val_RMSE=0.013098 best_ADE=0.008732 status=improved
# [cnn_gnn_transformer] epoch 06/30 train_loss=0.000509 val_loss=0.000048 val_ADE=0.009791 val_FDE=0.008189 val_RMSE=0.013822 best_ADE=0.008732 status=no_improve(1/5)
# [cnn_gnn_transformer] epoch 07/30 train_loss=0.000508 val_loss=0.000046 val_ADE=0.009347 val_FDE=0.007143 val_RMSE=0.013629 best_ADE=0.008732 status=no_improve(2/5)
# [cnn_gnn_transformer] epoch 08/30 train_loss=0.000508 val_loss=0.000042 val_ADE=0.008161 val_FDE=0.004397 val_RMSE=0.012995 best_ADE=0.008161 status=improved
# [cnn_gnn_transformer] epoch 09/30 train_loss=0.000509 val_loss=0.000043 val_ADE=0.008541 val_FDE=0.005594 val_RMSE=0.013085 best_ADE=0.008161 status=no_improve(1/5)
# [cnn_gnn_transformer] epoch 10/30 train_loss=0.000508 val_loss=0.000042 val_ADE=0.008231 val_FDE=0.004717 val_RMSE=0.013010 best_ADE=0.008161 status=no_improve(2/5)
# [cnn_gnn_transformer] epoch 11/30 train_loss=0.000507 val_loss=0.000045 val_ADE=0.009025 val_FDE=0.005889 val_RMSE=0.013427 best_ADE=0.008161 status=no_improve(3/5)
# [cnn_gnn_transformer] epoch 12/30 train_loss=0.000509 val_loss=0.000064 val_ADE=0.012812 val_FDE=0.012925 val_RMSE=0.016000 best_ADE=0.008161 status=no_improve(4/5)
# [cnn_gnn_transformer] epoch 13/30 train_loss=0.000509 val_loss=0.000043 val_ADE=0.008288 val_FDE=0.004868 val_RMSE=0.013082 best_ADE=0.008161 status=no_improve(5/5)
# [cnn_gnn_transformer] early stopping at epoch 13 (best_epoch=8, best_val_ADE=0.008161)
# [cnn_gnn_transformer] done: best_epoch=8 best_val_ADE=0.008161
# [runtime] cnn_gnn_transformer_training done: start=2026-05-23T11:54:55 end=2026-05-23T12:04:39 elapsed_s=583.465 peak_cpu=54.20% peak_rss_mb=1408.46 peak_gpu_alloc_mb=60.09
# [runtime] cnn_gnn_transformer_notebook_run done: start=2026-05-23T11:54:55 end=2026-05-23T12:04:47 elapsed_s=592.203 peak_cpu=100.00% peak_rss_mb=1409.01 peak_gpu_alloc_mb=60.09
# {
#   "ADE": 0.009386635385453701,
#   "FDE": 0.006006165873259306,
#   "RMSE": 0.014376955106854439,
#   "loss": 5.167421584446419e-05,
#   "model_slug": "cnn_gnn_transformer",
#   "timestamp": "20260523_115455",
#   "split_path": "/home/basudeo/Documents/Thesis/model_training/results/splits/trajectory_split_seed42_past10_future5.json",
#   "sample_table_path": "/home/basudeo/Documents/Thesis/model_training/results/train_ready/sample_table_seed42_past10_future5.json",
#   "best_epoch": 8,
#   "best_val_metrics": {
#     "ADE": 0.00816142838448286,
#     "FDE": 0.004396713338792324,
#     "RMSE": 0.012995004653930664,
#     "loss": 4.221753974900026e-05
#   },
#   "history_csv": "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/20260523_115455_training_history.csv",
#   "best_weight_path": "/home/basudeo/Documents/Thesis/model_training/model_weights/cnn_gnn_transformer/20260523_115455_best.pt",
#   "latest_weight_path": "/home/basudeo/Documents/Thesis/model_training/model_weights/cnn_gnn_transformer/latest.pt",
#   "training_runtime": {
#     "stage_name": "cnn_gnn_transformer_training",
#     "timestamp": "20260523_115455",
#     "wall_start_iso": "2026-05-23T11:54:55",
#     "wall_end_iso": "2026-05-23T12:04:39",
#     "elapsed_s": 583.465,
#     "sample_count": 574,
#     "context": {
#       "model_slug": "cnn_gnn_transformer",
#       "timestamp": "20260523_115455",
#       "epochs_requested": 30,
#       "patience": 5,
#       "train_sample_count": 36405,
#       "val_sample_count": 6082,
#       "test_sample_count": 9219,
#       "train_batch_count": 569,
#       "val_batch_count": 96,
#       "test_batch_count": 145,
#       "batch_size": 64,
#       "model_class": "CNNGNNTransformerTrajectoryPredictor",
#       "parameter_count": 403050,
#       "trainable_parameter_count": 403050,
#       "episode_count": 8,
#       "total_frame_count": 51818,
#       "sample_count": 51706,
#       "frame_file_count": 8,
#       "frame_files_total_size_mb": 56.592,
#       "manifest_files_total_size_mb": 0.005,
#       "sample_table_size_mb": 42.886,
#       "split_file_size_mb": 3.195,
#       "split_strategy": "episode",
#       "train_episode_count": 5,
#       "val_episode_count": 1,
#       "test_episode_count": 2
#     },
#     "avg_system_cpu_percent": 18.917,
#     "peak_system_cpu_percent": 54.2,
#     "avg_system_memory_percent": 31.663,
#     "peak_system_memory_percent": 45.0,
#     "avg_process_cpu_percent": 185.245,
#     "peak_process_cpu_percent": 223.7,
#     "avg_process_rss_mb": 1388.675,
#     "peak_process_rss_mb": 1408.457,
#     "peak_gpu_memory_allocated_mb": 57.54,
#     "peak_gpu_memory_reserved_mb": 86.0,
#     "peak_gpu_max_memory_allocated_mb": 60.09,
#     "peak_gpu_max_memory_reserved_mb": 86.0,
#     "min_gpu_memory_free_mb": 5391.062,
#     "gpu_memory_total_mb": 5928.438,
#     "summary_path": "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/runtime/20260523_115455_cnn_gnn_transformer_training_runtime_summary.json",
#     "samples_path": "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/runtime/20260523_115455_cnn_gnn_transformer_training_runtime_samples.csv",
#     "epochs_requested": 30,
#     "epochs_completed": 13,
#     "best_epoch": 8,
#     "train_sample_count": 36405,
#     "val_sample_count": 6082,
#     "train_batch_count": 569,
#     "val_batch_count": 96,
#     "total_processed_train_samples": 473265,
#     "total_processed_val_samples": 79066
#   },
#   "notebook_runtime": {
#     "stage_name": "cnn_gnn_transformer_notebook_run",
#     "timestamp": "20260523_115455",
#     "wall_start_iso": "2026-05-23T11:54:55",
#     "wall_end_iso": "2026-05-23T12:04:47",
#     "elapsed_s": 592.203,
#     "sample_count": 583,
#     "context": {
#       "model_slug": "cnn_gnn_transformer",
#       "timestamp": "20260523_115455",
#       "past_len": 10,
#       "future_len": 5,
#       "train_sample_count": 36405,
#       "val_sample_count": 6082,
#       "test_sample_count": 9219,
#       "train_batch_count": 569,
#       "val_batch_count": 96,
#       "test_batch_count": 145,
#       "batch_size": 64,
#       "model_class": "CNNGNNTransformerTrajectoryPredictor",
#       "parameter_count": 403050,
#       "trainable_parameter_count": 403050
#     },
#     "avg_system_cpu_percent": 19.085,
#     "peak_system_cpu_percent": 100.0,
#     "avg_system_memory_percent": 31.666,
#     "peak_system_memory_percent": 44.6,
#     "avg_process_cpu_percent": 186.933,
#     "peak_process_cpu_percent": 973.8,
#     "avg_process_rss_mb": 1388.667,
#     "peak_process_rss_mb": 1409.008,
#     "peak_gpu_memory_allocated_mb": 57.717,
#     "peak_gpu_memory_reserved_mb": 86.0,
#     "peak_gpu_max_memory_allocated_mb": 60.09,
#     "peak_gpu_max_memory_reserved_mb": 86.0,
#     "min_gpu_memory_free_mb": 5391.062,
#     "gpu_memory_total_mb": 5928.438,
#     "summary_path": "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/runtime/20260523_115455_cnn_gnn_transformer_notebook_run_runtime_summary.json",
#     "samples_path": "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/runtime/20260523_115455_cnn_gnn_transformer_notebook_run_runtime_samples.csv",
#     "train_sample_count": 36405,
#     "val_sample_count": 6082,
#     "test_sample_count": 9219,
#     "train_batch_count": 569,
#     "val_batch_count": 96,
#     "test_batch_count": 145,
#     "batch_size": 64,
#     "model_class": "CNNGNNTransformerTrajectoryPredictor",
#     "parameter_count": 403050,
#     "trainable_parameter_count": 403050
#   },
#   "prediction_export_path": "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/20260523_115455_trajectory_predictions.npz",
#   "overlay_paths": [
#     "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/plots/20260523_115455_trajectory_overlay_00.png",
#     "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/plots/20260523_115455_trajectory_overlay_01.png",
#     "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/plots/20260523_115455_trajectory_overlay_02.png",
#     "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/plots/20260523_115455_trajectory_overlay_03.png",
#     "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/plots/20260523_115455_trajectory_overlay_04.png",
#     "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/plots/20260523_115455_trajectory_overlay_05.png",
#     "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/plots/20260523_115455_trajectory_overlay_06.png",
#     "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/plots/20260523_115455_trajectory_overlay_07.png"
#   ],
#   "step_error_plot": "/home/basudeo/Documents/Thesis/model_training/results/cnn_gnn_transformer/plots/20260523_115455_mean_step_error.png"
# }
